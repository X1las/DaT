# %% [markdown]
# # Imports

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Testing

# %%
x = [1, 2, 3, 4, 5]
y = [10, 15, 13, 17, 20]

plt.plot(x, y)
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Sample Plot')
# Out:
# Text(0.5, 1.0, 'Sample Plot')

# %%
df = pd.DataFrame({
    'A': np.random.rand(50),
    'B': np.random.rand(50)
})
df.head()
# Out:
#           A         B
# 0  0.889443  0.254417
# 1  0.432279  0.495012
# 2  0.735375  0.260365
# 3  0.215000  0.348242
# 4  0.534731  0.912904

# %%
data = pd.read_csv("Data/adult.csv")
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
excel_data = pd.read_excel("Excel/Webanalytics_data_example.xlsx",sheet_name='Dataset1')

excel_data[excel_data["PercentNewSessions"] > .5].sort_values(by="PercentNewSessions", ascending=False)
# Out:
#      MediaChannel  Sessions  PercentNewSessions  NewUsers  BounceRate  \
# 1          Social     59398            0.943315     56031    0.542375
# 5         Display      6411            0.850257      5451    0.834191
# 0  Organic_Search     76852            0.784092     60259    0.394837
# 3          Direct     26348            0.758653     19989    0.459466
# 2     Paid_Search     31882            0.666395     21246    0.621918
# 4        Referral     18762            0.530540      9954    0.269961
#
#    PagesPerSession  AvgSessionDuration  Transactions    Revenue
# 1         3.232348          111.798832            38    1692.29
# 5         2.359850           34.354703            34    7956.42
# 0         7.225290          161.326342           989   94966.75
# 3         6.277820          162.812206           367   52054.79
# 2         4.461326           97.984129           425   21515.42
# 4        12.226149          259.000320          1231  202558.88

# %%
sns.scatterplot(data=excel_data, x="Sessions", y="PagesPerSession", hue="PercentNewSessions", size="BounceRate", sizes=(20, 200))
plt.title('Sessions vs PagesPerSession with PercentNewSessions and BounceRate')
plt.show()
